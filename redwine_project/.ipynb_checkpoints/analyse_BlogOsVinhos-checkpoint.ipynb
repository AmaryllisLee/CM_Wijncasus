# %% [markdown]
# # Analysis dataset

# %%
# load dataset
import pandas as pd
df = pd.read_excel ('BlogOsVinhos.xlsx')
df
#df = pd.read_csv('BlogOsVinhos.xlsx', encoding  = "cp1252", delimiter = ';')
# Out:
#                                              Name                  Region  \
# 0                                       .Beb 2007       Regional Alentejo
# 1                                       .Beb 2009       Regional Alentejo
# 2                                       .Beb 2010       Regional Alentejo
# 3                                       .Beb 2011       Regional Alentejo
# 4                                       .Beb 2012       Regional Alentejo
# 5                                       .Beb 2013       Regional Alentejo
# 6                             .Beb Selection 2012       Regional Alentejo
# 7                             .Beb Selection 2014       Regional Alentejo
# 8                                       .Com 2007       Regional Alentejo
# 9                                       .Com 2009       Regional Alentejo
# 10                                      .Com 2010       Regional Alentejo
# 11                              .Com Premium 2011       Regional Alentejo
# ...

# %%
df.shape
# Out:
# (2993, 15)

# %%
df.describe()
# Out:
#               Year  AlcoholPercentage  MinimunPrice  MaximumPrice  JudgeRating
# count  2993.000000        2993.000000   2993.000000   2993.000000  2993.000000
# mean   1999.868694          13.405112      9.657701     14.688573    15.639492
# std     130.829079           0.939524      8.548043     40.881400     1.130448
# min      -1.000000          -1.000000     -1.000000     -1.000000    -1.000000
# 25%    2005.000000          13.000000      4.000000      7.500000    15.000000
# 50%    2009.000000          13.500000      7.500000     10.000000    15.500000
# 75%    2013.000000          14.000000     12.500000     15.000000    16.500000
# max    2018.000000          17.000000    155.000000   2150.000000    19.000000

# %%
df['JudgeRating'].describe()
# Out:
# count    2993.000000
# mean       15.639492
# std         1.130448
# min        -1.000000
# 25%        15.000000
# 50%        15.500000
# 75%        16.500000
# max        19.000000
# Name: JudgeRating, dtype: float64

# %%
df.boxplot(column = ['JudgeRating'])

# %%
df.dtypes
# Out:
# Name                  object
# Region                object
# Year                   int64
# Color                 object
# Castes                object
# AlcoholPercentage    float64
# Producer              object
# MinimunPrice         float64
# MaximumPrice         float64
# Judge                 object
# JudgeRating          float64
# Date                  object
# JudgeNotes            object
# Label                 object
# Link                  object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name                  0
# Region                4
# Year                  0
# Color                 0
# Castes                4
# AlcoholPercentage     0
# Producer              0
# MinimunPrice          0
# MaximumPrice          0
# Judge                 0
# JudgeRating           0
# Date                 23
# JudgeNotes            1
# Label                 1
# Link                  0
# dtype: int64
